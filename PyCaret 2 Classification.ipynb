# %% [markdown]
# # PyCaret 2 Classification Example
# This notebook is created using PyCaret 2.0. Last updated : 28-07-2020

# %%
# check version
from pycaret.utils import version
version()
# Out:
# pycaret-nightly-0.39

# %% [markdown]
# # 1. Data Repository

# %%
from pycaret.datasets import get_data
index = get_data('index')
# Out:
#             Dataset    Data Types                 Default Task  \
# 0           anomaly  Multivariate            Anomaly Detection
# 1            france  Multivariate      Association Rule Mining
# 2           germany  Multivariate      Association Rule Mining
# 3              bank  Multivariate      Classification (Binary)
# 4             blood  Multivariate      Classification (Binary)
# 5            cancer  Multivariate      Classification (Binary)
# 6            credit  Multivariate      Classification (Binary)
# 7          diabetes  Multivariate      Classification (Binary)
# 8   electrical_grid  Multivariate      Classification (Binary)
# 9          employee  Multivariate      Classification (Binary)
# 10            heart  Multivariate      Classification (Binary)
# 11    heart_disease  Multivariate      Classification (Binary)
# 12        hepatitis  Multivariate      Classification (Binary)
# 13           income  Multivariate      Classification (Binary)
# 14            juice  Multivariate      Classification (Binary)
# 15              nba  Multivariate      Classification (Binary)
# 16             wine  Multivariate      Classification (Binary)
# 17        telescope  Multivariate      Classification (Binary)
# 18            glass  Multivariate  Classification (Multiclass)
# 19             iris  Multivariate  Classification (Multiclass)
# 20            poker  Multivariate  Classification (Multiclass)
# 21        questions  Multivariate  Classification (Multiclass)
# 22        satellite  Multivariate  Classification (Multiclass)
# 23         asia_gdp  Multivariate                   Clustering
# 24        elections  Multivariate                   Clustering
# 25         facebook  Multivariate                   Clustering
# 26              ipl  Multivariate                   Clustering
# 27        jewellery  Multivariate                   Clustering
# 28             mice  Multivariate                   Clustering
# 29        migration  Multivariate                   Clustering
# 30          perfume  Multivariate                   Clustering
# 31          pokemon  Multivariate                   Clustering
# 32       population  Multivariate                   Clustering
# 33    public_health  Multivariate                   Clustering
# 34            seeds  Multivariate                   Clustering
# 35        wholesale  Multivariate                   Clustering
# 36           tweets          Text                          NLP
# 37           amazon          Text         NLP / Classification
# 38             kiva          Text         NLP / Classification
# 39              spx          Text             NLP / Regression
# 40        wikipedia          Text         NLP / Classification
# 41       automobile  Multivariate                   Regression
# 42             bike  Multivariate                   Regression
# 43           boston  Multivariate                   Regression
# 44         concrete  Multivariate                   Regression
# 45          diamond  Multivariate                   Regression
# 46           energy  Multivariate                   Regression
# 47           forest  Multivariate                   Regression
# 48             gold  Multivariate                   Regression
# 49            house  Multivariate                   Regression
# 50        insurance  Multivariate                   Regression
# 51       parkinsons  Multivariate                   Regression
# 52          traffic  Multivariate                   Regression
#
#                 Target Variable  # Instances  # Attributes Missing Values
# 0                          None         1000            10              N
# 1        InvoiceNo, Description         8557             8              N
# 2        InvoiceNo, Description         9495             8              N
# 3                       deposit        45211            17              N
# 4                         Class          748             5              N
# 5                         Class          683            10              N
# 6                       default        24000            24              N
# 7                Class variable          768             9              N
# 8                         stabf        10000            14              N
# 9                          left        14999            10              N
# 10                        DEATH          200            16              N
# 11                      Disease          270            14              N
# 12                        Class          154            32              Y
# 13                  income >50K        32561            14              Y
# 14                     Purchase         1070            15              N
# 15                  TARGET_5Yrs         1340            21              N
# 16                         type         6498            13              N
# 17                        Class        19020            11              N
# 18                         Type          214            10              N
# 19                      species          150             5              N
# 20                        CLASS       100000            11              N
# 21                Next_Question          499             4              N
# 22                        Class         6435            37              N
# 23                         None           40            11              N
# 24                         None         3195            54              Y
# 25                         None         7050            12              N
# 26                         None          153            25              N
# 27                         None          505             4              N
# 28                         None         1080            82              Y
# 29                         None          233            12              N
# 30                         None           20            29              N
# 31                         None          800            13              Y
# 32                         None          255            56              Y
# 33                         None          224            21              N
# 34                         None          210             7              N
# 35                         None          440             8              N
# 36                        tweet         8594             2              N
# 37                   reviewText        20000             2              N
# 38                           en         6818             7              N
# 39                         text          874             4              N
# 40                         Text          500             3              N
# 41                        price          202            26              Y
# 42                          cnt        17379            15              N
# 43                         medv          506            14              N
# 44                     strength         1030             9              N
# 45                        Price         6000             8              N
# 46  Heating Load / Cooling Load          768            10              N
# 47                         area          517            13              N
# 48                    Gold_T+22         2558           121              N
# 49                    SalePrice         1461            81              Y
# 50                      charges         1338             7              N
# 51                          PPE         5875            22              N
# 52               traffic_volume        48204             8              N

# %%
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0   0.000000   0.000000           0.24      1
# 1   0.150754   0.000000           0.24      1
# 2   0.000000   0.091398           0.23      1
# 3   0.000000   0.000000           0.00      1
# 4   0.000000   0.000000           0.00      0

# %% [markdown]
# # 2. Initialize Setup

# %%
from pycaret.classification import *
clf1 = setup(data, target = 'Purchase', session_id=123, log_experiment=False, experiment_name='bank1')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_c6cced64_d1c1_11ea_b44e_482ae32b83da" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow2_col1" class="data row2 col1" >CH: 0, MM: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow3_col1" class="data row3 col1" >(1070, 19)</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow5_col1" class="data row5 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow6_col1" class="data row6 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow10_col1" class="data row10 col1" >(1070, 19)</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow11_col1" class="data row11 col1" >(748, 28)</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow12_col1" class="data row12 col1" >(322, 28)</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c6cced64_d1c1_11ea_b44e_482ae32b83dalevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_c6cced64_d1c1_11ea_b44e_482ae32b83darow18_col1" class="data row18 col1" >None</td>
#             </tr>

# %% [markdown]
# # 3. Compare Baseline

# %%
top5 = compare_models(n_select=5)
# Out:
# <style  type="text/css" >
#     #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83da th {
#           text-align: left;
#     }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col0 {
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col7 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow0_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col0 {
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col7 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow1_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col0 {
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col7 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow2_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col0 {
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col7 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow3_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col0 {
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col7 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow4_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col0 {
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col7 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow5_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col0 {
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col7 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow6_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow7_col0 {
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_ed71bd46_d1c1_11ea_ac4d_482ae32b83darow7_col5 {
#             : ;
#             text-align:  left;

# %%
top5_tuned = [tune_model(i) for i in top5]
# Out:
# <style  type="text/css" >
#     #T_01cec812_d1c2_11ea_9f4f_482ae32b83darow10_col0 {
#             background:  yellow;
#         }    #T_01cec812_d1c2_11ea_9f4f_482ae32b83darow10_col1 {
#             background:  yellow;
#         }    #T_01cec812_d1c2_11ea_9f4f_482ae32b83darow10_col2 {
#             background:  yellow;
#         }    #T_01cec812_d1c2_11ea_9f4f_482ae32b83darow10_col3 {
#             background:  yellow;
#         }    #T_01cec812_d1c2_11ea_9f4f_482ae32b83darow10_col4 {
#             background:  yellow;
#         }    #T_01cec812_d1c2_11ea_9f4f_482ae32b83darow10_col5 {
#             background:  yellow;
#         }    #T_01cec812_d1c2_11ea_9f4f_482ae32b83darow10_col6 {
#             background:  yellow;
#         }</style><table id="T_01cec812_d1c2_11ea_9f4f_482ae32b83da" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_01cec812_d1c2_11ea_9f4f_482ae32b83dalevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow0_col0" class="data row0 col0" >0.7467</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow0_col1" class="data row0 col1" >0.8426</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow0_col2" class="data row0 col2" >0.6897</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow0_col3" class="data row0 col3" >0.6667</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow0_col4" class="data row0 col4" >0.6780</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow0_col5" class="data row0 col5" >0.4693</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow0_col6" class="data row0 col6" >0.4695</td>
#             </tr>
#             <tr>
#                         <th id="T_01cec812_d1c2_11ea_9f4f_482ae32b83dalevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow1_col0" class="data row1 col0" >0.8267</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow1_col1" class="data row1 col1" >0.9475</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow1_col2" class="data row1 col2" >0.7241</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow1_col3" class="data row1 col3" >0.8077</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow1_col4" class="data row1 col4" >0.7636</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow1_col5" class="data row1 col5" >0.6274</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow1_col6" class="data row1 col6" >0.6298</td>
#             </tr>
#             <tr>
#                         <th id="T_01cec812_d1c2_11ea_9f4f_482ae32b83dalevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow2_col0" class="data row2 col0" >0.7600</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow2_col1" class="data row2 col1" >0.8201</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow2_col2" class="data row2 col2" >0.6552</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow2_col3" class="data row2 col3" >0.7037</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow2_col4" class="data row2 col4" >0.6786</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow2_col5" class="data row2 col5" >0.4875</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow2_col6" class="data row2 col6" >0.4883</td>
#             </tr>
#             <tr>
#                         <th id="T_01cec812_d1c2_11ea_9f4f_482ae32b83dalevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow3_col0" class="data row3 col0" >0.8133</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow3_col1" class="data row3 col1" >0.9070</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow3_col2" class="data row3 col2" >0.8276</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow3_col3" class="data row3 col3" >0.7273</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow3_col4" class="data row3 col4" >0.7742</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow3_col5" class="data row3 col5" >0.6162</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow3_col6" class="data row3 col6" >0.6200</td>
#             </tr>
#             <tr>
#                         <th id="T_01cec812_d1c2_11ea_9f4f_482ae32b83dalevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow4_col0" class="data row4 col0" >0.7867</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow4_col1" class="data row4 col1" >0.8973</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow4_col2" class="data row4 col2" >0.8621</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow4_col3" class="data row4 col3" >0.6757</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow4_col4" class="data row4 col4" >0.7576</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow4_col5" class="data row4 col5" >0.5720</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow4_col6" class="data row4 col6" >0.5856</td>
#             </tr>
#             <tr>
#                         <th id="T_01cec812_d1c2_11ea_9f4f_482ae32b83dalevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow5_col0" class="data row5 col0" >0.8133</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow5_col1" class="data row5 col1" >0.8906</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow5_col2" class="data row5 col2" >0.7241</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow5_col3" class="data row5 col3" >0.7778</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow5_col4" class="data row5 col4" >0.7500</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow5_col5" class="data row5 col5" >0.6014</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow5_col6" class="data row5 col6" >0.6023</td>
#             </tr>
#             <tr>
#                         <th id="T_01cec812_d1c2_11ea_9f4f_482ae32b83dalevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow6_col0" class="data row6 col0" >0.8133</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow6_col1" class="data row6 col1" >0.8833</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow6_col2" class="data row6 col2" >0.8333</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow6_col3" class="data row6 col3" >0.7353</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow6_col4" class="data row6 col4" >0.7812</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_482ae32b83darow6_col5" class="data row6 col5" >0.6196</td>
#                         <td id="T_01cec812_d1c2_11ea_9f4f_4

# %% [markdown]
# # 4. Create Model

# %%
lr = create_model('lr', fold = 5)

# %%
dt = create_model('dt')

# %%
rf = create_model('rf', fold = 5)

# %%
models()

# %%
models(type='ensemble').index.tolist()

# %%
ensembled_models = compare_models(whitelist = models(type='ensemble').index.tolist(), fold = 3)

# %% [markdown]
# # 5. Tune Hyperparameters

# %%
tuned_lr = tune_model(lr)

# %%
tuned_rf = tune_model(rf)

# %% [markdown]
# # 6. Ensemble Model

# %%
bagged_dt = ensemble_model(dt)

# %%
boosted_dt = ensemble_model(dt, method = 'Boosting')

# %% [markdown]
# # 7. Blend Models

# %%
blender = blend_models(estimator_list = [boosted_dt, bagged_dt], method = 'soft')

# %% [markdown]
# # 8. Stack Models

# %%
stacker = stack_models(estimator_list = [boosted_dt,bagged_dt,tuned_rf], meta_model=rf)

# %% [markdown]
# # 9. Analyze Model

# %%
plot_model(rf)

# %%
plot_model(rf, plot = 'confusion_matrix')

# %%
plot_model(rf, plot = 'boundary')

# %%
evaluate_model(rf)

# %% [markdown]
# # 10. Interpret Model

# %%
catboost = create_model('catboost', cross_validation=False)

# %%
interpret_model(catboost)

# %%
interpret_model(catboost, plot = 'correlation')

# %%
interpret_model(catboost, plot = 'reason', observation = 12)

# %% [markdown]
# # 11. AutoML()

# %%
best = automl(optimize = 'Recall')
best

# %% [markdown]
# # 12. Predict Model

# %%
pred_holdouts = predict_model(lr)
pred_holdouts.head()

# %%
new_data = data.copy()
new_data.drop(['deposit'], axis=1, inplace=True)
predict_new = predict_model(lr, data=new_data)
predict_new.head()

# %% [markdown]
# # 13. Save / Load Model

# %%
save_model(lr, model_name='best-model')

# %%
loaded_bestmodel = load_model('best-model')
print(loaded_bestmodel)

# %%
from sklearn import set_config
set_config(display='diagram')
loaded_bestmodel[0]

# %%
from sklearn import set_config
set_config(display='text')

# %% [markdown]
# # 14. Deploy Model

# %%
deploy_model(lr, model_name = 'best-aws', authentication = {'bucket' : 'pycaret-test'})

# %% [markdown]
# # 15. Get Config / Set Config

# %%
X_train = get_config('X_train')
X_train.head()

# %%
get_config('seed')

# %%
from pycaret.classification import set_config
set_config('seed', 999)

# %%
get_config('seed')

# %% [markdown]
# # 16. Get System Logs

# %%
get_system_logs()

# %% [markdown]
# # 17. MLFlow UI

# %%
# !mlflow ui

# %%
# to generate csv file with experiment logs
get_logs()

# %% [markdown]
# # End
# Thank you. For more information / tutorials on PyCaret, please visit https://www.pycaret.org
